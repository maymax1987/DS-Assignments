# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew

# %% [markdown]
# # Descriptive Analytics for Numerical Columns

# %%
df = pd.read_csv('sales_data_with_discounts.csv', index_col=0)
df
# Out:
#                  Day  SKU City  Volume         BU  Brand       Model  \
# Date
# 01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ...              ...  ...  ...     ...        ...    ...         ...
# 15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#             Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# Date
# ...

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %%
df.dtypes
# Out:
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
s=df.select_dtypes(int)
s
# Out:
#             Volume  Avg Price  Total Sales Value
# Date
# 01-04-2021      15      12100             181500
# 01-04-2021      10      10100             101000
# 01-04-2021       7      16100             112700
# 01-04-2021       6      20100             120600
# 01-04-2021       3       8100              24300
# ...            ...        ...                ...
# 15-04-2021       2       1300               2600
# 15-04-2021       6       2600              15600
# 15-04-2021       2       1600               3200
# 15-04-2021       3       1900               5700
# 15-04-2021       1       3100               3100
#
# [450 rows x 3 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
s.mean()
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# dtype: float64

# %%
s.median()
# Out:
# Volume                  4.0
# Avg Price            1450.0
# Total Sales Value    5700.0
# dtype: float64

# %%
s.mode()
# Out:
#    Volume  Avg Price  Total Sales Value
# 0     3.0        400            24300.0
# 1     NaN        450                NaN
# 2     NaN        500                NaN
# 3     NaN       1300                NaN
# 4     NaN       8100                NaN

# %%
print(s.std())
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# dtype: float64

# %% [markdown]
# # interpretation of these statistics
# Statistics is like a toolkit we use to understand and make sense of information. It helps us collect, organize, analyze, and interpret data to find patterns, trends, and relationships in the world around us.

# %% [markdown]
# # Data Visualization

# %%
s.hist()
# Out:
# array([[<Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Avg Price'}>],
#        [<Axes: title={'center': 'Total Sales Value'}>, <Axes: >]],
#       dtype=object)

# %%
print(skew(s, axis=0, bias=True))
# Out:
# [2.72260944 1.90250427 1.52960882]

# %%
s.describe()[['Volume', 'Avg Price', 'Total Sales Value' ]]
# Out:
#            Volume     Avg Price  Total Sales Value
# count  450.000000    450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556
# std      4.231602  18079.904840       50535.074173
# min      1.000000    290.000000         400.000000
# 25%      3.000000    465.000000        2700.000000
# 50%      4.000000   1450.000000        5700.000000
# 75%      6.000000  10100.000000       53200.000000
# max     31.000000  60100.000000      196400.000000

# %%
s.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # Bar Chart Analysis for Categorical Column:

# %%
df.head()
# Out:
#                  Day  SKU City  Volume       BU  Brand       Model  Avg Price  \
# Date
# 01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10      12100
# 01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus      10100
# 01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99      16100
# 01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus      20100
# 01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98        8100
#
#             Total Sales Value  Discount Rate (%)  Discount Amount  \
# Date
# 01-04-2021             181500          11.654820     21153.498820
# 01-04-2021             101000          11.560498     11676.102961
# 01-04-2021             112700           9.456886     10657.910157
# 01-04-2021             120600           6.935385      8364.074702
# 01-04-2021              24300          17.995663      4372.946230
#
#             Net Sales Value
# Date
# 01-04-2021    160346.501180
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category']).columns

# %%
for col in categorical_columns:
    plt.figure(figsize=(10, 6))
    df[col].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')
    plt.title(f'Frequency Distribution of {col}', fontsize=16)
    plt.xlabel(col, fontsize=14)
    plt.ylabel('Count', fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# # Conversion of Categorical Data into Dummy Variables

# %%
df = pd.get_dummies(data=df,columns= ['Day','SKU','City','BU','Brand','Model'], dtype=int)

# %%
df
# Out:
#             Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# Date
# 01-04-2021      15      12100             181500          11.654820
# 01-04-2021      10      10100             101000          11.560498
# 01-04-2021       7      16100             112700           9.456886
# 01-04-2021       6      20100             120600           6.935385
# 01-04-2021       3       8100              24300          17.995663
# ...            ...        ...                ...                ...
# 15-04-2021       2       1300               2600          15.475687
# 15-04-2021       6       2600              15600          17.057027
# 15-04-2021       2       1600               3200          18.965550
# 15-04-2021       3       1900               5700          16.793014
# 15-04-2021       1       3100               3100          15.333300
#
#             Discount Amount  Net Sales Value  Day_Friday  Day_Monday  \
# Date
# ...

# %% [markdown]
# # Standardization of Numerical Variables

# %% [markdown]
#     x−μ
# z= ______
#      σ

# %% [markdown]
#  Standardization, often referred to as z-score normalization, is a data preprocessing technique used in statistical and machine learning applications to transform features so that they have a mean of 0 and a standard deviation of 1.
#
# Formula for Standardization (Z-Score Normalization):

# %% [markdown]
# x: The original value of the data point.
#
# μ: The mean (average) of the feature.
#
# σ: The standard deviation of the feature.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
sc = StandardScaler()

# %%
sc.fit_transform(df)
# Out:
# array([[ 2.35002911,  0.091173  ,  2.92572115, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 1.16712855, -0.01957016,  1.33099521, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 0.45738822,  0.31265934,  1.56277525, ..., -0.18569534,
#          5.38516481, -0.18569534],
#        ...,
#        [-0.72551234, -0.49022863, -0.60644824, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.48893223, -0.47361715, -0.55692259, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.96209245, -0.40717125, -0.60842926, ..., -0.18569534,
#         -0.18569534, -0.18569534]])

# %%
scaled_data = pd.DataFrame(sc.fit_transform(df), columns=df.columns)
scaled_data
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value  Day_Friday  Day_Monday  Day_Saturday  \
# 0           3.952816         2.804756   -0.392232   -0.392232     -0.392232
# ...

# %%
scaled_data.describe()
# Out:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   6.118562e-17  3.157968e-17       1.578984e-17      -3.552714e-17
# std    1.001113e+00  1.001113e+00       1.001113e+00       1.001113e+00
# min   -9.620925e-01 -5.627654e-01      -6.619170e-01      -2.406935e+00
# 25%   -4.889322e-01 -5.530754e-01      -6.163534e-01      -2.823066e-01
# 50%   -2.523521e-01 -4.985344e-01      -5.569226e-01       3.374180e-01
# 75%    2.208081e-01 -1.957016e-02       3.840648e-01       7.019781e-01
# max    6.135311e+00  2.749009e+00       3.220894e+00       1.147360e+00
#
#        Discount Amount  Net Sales Value    Day_Friday    Day_Monday  \
# count     4.500000e+02     4.500000e+02  4.500000e+02  4.500000e+02
# mean     -5.526444e-17     1.973730e-17 -9.473903e-17 -1.105289e-16
# std       1.001113e+00     1.001113e+00  1.001113e+00  1.001113e+00
# ...
